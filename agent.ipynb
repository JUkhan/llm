# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
import pandas as pd
data = pd.read_csv('population.csv')
print(data.head(3))
# Out:
#          Country  Population
# 0          China  1425887337
# 1          India  1417173173
# 2  United States   336997624

# %%
from pandasai import Agent

agent=Agent(data)

# %%
agent.chat('Which are the top 5 countries by population?')
# Out:
#          Country  Population
# 0          China  1425887337
# 1          India  1417173173
# 2  United States   336997624
# 3      Indonesia   277534123
# 4       Pakistan   240485658

# %%
agent.chat('First sort the countries by population and then \
        calculate the total population of the top 3 countries by population')
# Out:
# 3180058134

# %%
agent.chat('First sort countries by population and then create a bar plot\
        of the top 5 countries')
# Out:
# 'd:/llm/exports/charts/temp_chart.png'
